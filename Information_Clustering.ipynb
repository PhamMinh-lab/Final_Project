# %%
import pandas as pd
import numpy as np
import re
import regex
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from underthesea import word_tokenize, sent_tokenize, pos_tag
from imblearn.over_sampling import SMOTE
from sklearn.metrics import silhouette_score

# %%
# Bước 1: Load dữ liệu
# Load data
df = pd.read_excel("reviews.xlsx")
df = df.dropna(subset=["Title", "What I liked", "Suggestions for improvement"])
df['positive_text'] = df['What I liked']
df['negative_text'] = df['Suggestions for improvement']
df['sentiment'] = df['Rating'].apply(lambda x: 'negative' if x <= 2 else 'positive' if x >= 4 else 'neutral')

df.head()
# Out:
#    id Company Name        Cmt_day  \
# 0   4    Accenture     March 2025
# 1   4    Accenture   January 2025
# 2   4    Accenture   October 2023
# 3   4    Accenture  February 2025
# 4   4    Accenture  February 2023
#
#                                                Title  \
# 0  Môi trường thoải mái, ít áp lực, có thể làm vi...
# 1                        Công ty trẻ trung năng động
# 2               Môi trường làm việc thoải mái vui vẻ
# 3                       good environment for fresher
# 4              Môi trường làm việc thoải mái, vui vẻ
#
#                                         What I liked  \
# 0  Môi trường thoải mái, ít áp lực, có thể làm vi...
# 1  Cơ sở vật chất đẹp, công ty trẻ trung năng độn...
# 2  Mội người thân thiện, giúp đỡ lẫn nhau. Chương...
# 3  good env. for fresher to learn and improve the...
# 4  - Văn phòng đẹp, cơ sở vật chất tốt\n- Sếp và ...
#
#                          Suggestions for improvement  Rating  \
# 0  Cần đánh giá KPI khách quan và phân chia công ...       4
# 1  Nên nghiên cứu lại range lương của thì trường....       4
# 2  Do công ty làm outsourcing về mảng system nên ...       3
# 3  Need to forcus more on benefit and evaluate co...       3
# 4  - Phát triển văn phòng để rộng rãi hơn\n- Công...       4
#
#    Salary & benefits  Training & learning  Management cares about me  \
# 0                  4                    4                          4
# 1                  3                    4                          4
# 2                  3                    3                          3
# 3                  2                    2                          3
# 4                  3                    4                          4
#
#    Culture & fun  Office & workspace Recommend?  \
# 0              4                   4        Yes
# 1              4                   5        Yes
# 2              3                   3        Yes
# 3              4                   4         No
# 4              4                   3        Yes
#
#                                        positive_text  \
# 0  Môi trường thoải mái, ít áp lực, có thể làm vi...
# 1  Cơ sở vật chất đẹp, công ty trẻ trung năng độn...
# 2  Mội người thân thiện, giúp đỡ lẫn nhau. Chương...
# 3  good env. for fresher to learn and improve the...
# 4  - Văn phòng đẹp, cơ sở vật chất tốt\n- Sếp và ...
#
#                                        negative_text sentiment
# 0  Cần đánh giá KPI khách quan và phân chia công ...  positive
# 1  Nên nghiên cứu lại range lương của thì trường....  positive
# 2  Do công ty làm outsourcing về mảng system nên ...   neutral
# 3  Need to forcus more on benefit and evaluate co...   neutral
# 4  - Phát triển văn phòng để rộng rãi hơn\n- Công...  positive

# %%
##LOAD EMOJICON
file = open('file/emojicon.txt', 'r', encoding="utf8")
emoji_lst = file.read().split('\n')
emoji_dict = {}
for line in emoji_lst:
    key, value = line.split('\t')
    emoji_dict[key] = str(value)
#print(teen_dict)
file.close()
#################
#LOAD TEENCODE
file = open('file/teencode.txt', 'r', encoding="utf8")
teen_lst = file.read().split('\n')
teen_dict = {}
for line in teen_lst:
    key, value = line.split('\t')
    teen_dict[key] = str(value)
#print(teen_dict)
file.close()
###############
#LOAD TRANSLATE ENGLISH -> VNMESE
file = open('file/english-vnmese.txt', 'r', encoding="utf8")
englist_lst = file.read().split('\n')
for line in englist_lst:
    key, value = line.split('\t')
    teen_dict[key] = str(value)
#print(teen_dict)
file.close()
################
#LOAD wrong words
file = open('file/wrong-word.txt', 'r', encoding="utf8")
wrong_lst = file.read().split('\n')
file.close()
#################
#LOAD STOPWORDS
file = open('file/vietnamese-stopwords.txt', 'r', encoding="utf8")
stopwords_lst = file.read().split('\n')
file.close()

# %%
def process_text(text, dict_emoji, dict_teen, dict_eng_vn, lst_wrong):
    document = text.lower()
    document = document.replace("’",'')
    document = regex.sub(r'\.+', ".", document)
    document = re.sub(r'(.)\1+', r'\1', text) # thay thế lònggggg --> lòng
    new_sentence =''
    for sentence in sent_tokenize(document):
        # if not(sentence.isascii()):
        ###### CONVERT EMOJICON
        sentence = ''.join(dict_emoji[word]+' ' if word in dict_emoji else word for word in list(sentence))
        ###### CONVERT TEENCODE
        sentence = ' '.join(dict_teen[word] if word in dict_teen else word for word in sentence.split())
        ###### CONVERT ENGLISH TO VIETNAMESE
        sentence = ' '.join(dict_eng_vn[word] if word in dict_eng_vn else word for word in sentence.split())
        ###### DEL Punctuation & Numbers
        pattern = r'(?i)\b[a-záàảãạăắằẳẵặâấầẩẫậéèẻẽẹêếềểễệóòỏõọôốồổỗộơớờởỡợíìỉĩịúùủũụưứừửữựýỳỷỹỵđ]+\b'
        sentence = ' '.join(regex.findall(pattern,sentence))
        ###### DEL wrong words
        sentence = ' '.join('' if word in lst_wrong else word for word in sentence.split())
        new_sentence = new_sentence+ sentence + '. '
    document = new_sentence
    #print(document)
     ###### DEL excess blank space
    document = regex.sub(r'\s+', ' ', document).strip()
    return document

# %%
def loaddicchar():
    uniChars = "àáảãạâầấẩẫậăằắẳẵặèéẻẽẹêềếểễệđìíỉĩịòóỏõọôồốổỗộơờớởỡợùúủũụưừứửữựỳýỷỹỵÀÁẢÃẠÂẦẤẨẪẬĂẰẮẲẴẶÈÉẺẼẸÊỀẾỂỄỆĐÌÍỈĨỊÒÓỎÕỌÔỒỐỔỖỘƠỜỚỞỠỢÙÚỦŨỤƯỪỨỬỮỰỲÝỶỸỴÂĂĐÔƠƯ"
    unsignChars = "aaaaaaaaaaaaaaaaaeeeeeeeeeeediiiiiooooooooooooooooouuuuuuuuuuuyyyyyAAAAAAAAAAAAAAAAAEEEEEEEEEEEDIIIOOOOOOOOOOOOOOOOOOOUUUUUUUUUUUYYYYYAADOOU"

    dic = {}
    char1252 = 'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ'.split(
        '|')
    charutf8 = "à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ".split(
        '|')
    for i in range(len(char1252)):
        dic[char1252[i]] = charutf8[i]
    return dic

# Đưa toàn bộ dữ liệu qua hàm này để chuẩn hóa lại
def covert_unicode(txt):
    dicchar = loaddicchar()
    return regex.sub(
        r'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ',
        lambda x: dicchar[x.group()], txt)

# %%
def process_special_word(text):
    new_text = ''
    text_lst = text.split()
    i= 0
    if 'không' in text_lst:
        while i <= len(text_lst) - 1:
            word = text_lst[i]
            #print(word)
            #print(i)
            if  word == 'không':
                next_idx = i+1
                if next_idx <= len(text_lst) -1:
                    word = word +'_'+ text_lst[next_idx]
                i= next_idx + 1
            else:
                i = i+1
            new_text = new_text + word + ' '
    else:
        new_text = text
    return new_text.strip()

# %%
def process_postag_thesea(text):
    new_document = ''
    for sentence in sent_tokenize(text):
        sentence = sentence.replace('.','')
        ###### POS tag
        lst_word_type = ['A','AB','V','VB','VY','R']
        sentence = ' '.join( word[0] if word[1].upper() in lst_word_type else '' for word in pos_tag(process_special_word(word_tokenize(sentence, format="text"))))
        new_document = new_document + sentence + ' '
    ###### DEL excess blank space
    new_document = regex.sub(r'\s+', ' ', new_document).strip()
    return new_document

# %%
def remove_stopword(text, stopwords):
    ###### REMOVE stop words
    document = ' '.join('' if word in stopwords else word for word in text.split())
    #print(document)
    ###### DEL excess blank space
    document = regex.sub(r'\s+', ' ', document).strip()
    return document

# %%
# Apply preprocessing
df['positive_clean'] = df['positive_text'].apply(lambda x: process_text(str(x), emoji_dict, englist_lst, teen_dict,wrong_lst)) \
                                       .apply(covert_unicode) \
                                       .apply(process_special_word) \
                                       .apply(lambda x: remove_stopword(str(x), stopwords_lst)) \
                                       .apply(process_postag_thesea)
df['negative_clean'] = df['negative_text'].apply(lambda x: process_text(str(x), emoji_dict,englist_lst, teen_dict, wrong_lst)) \
                                       .apply(covert_unicode) \
                                       .apply(process_special_word) \
                                       .apply(lambda x: remove_stopword(str(x), stopwords_lst)) \
                                       .apply(process_postag_thesea)

# %%
df['positive_clean']
# Out:
# 0       thoải_mái hybrid thỏa_thuận tốt đủ dịch_vụ cải...
# 1                               đẹp trẻ kết_hợp dự_án thể
# 2       thân_thiện lẫn chuyên_nghiệp tổ_chức Khá yêu_c...
# 3                                    ability opened teams
# 4       đẹp vật_chất tốt đồng_nghiệp Đồng_nghiệp vẻ th...
#                               ...
# 8412    ấn_tượng vấn fedback Macbok bàn_phím dự_án tra...
# 8413    thoải_mái kiến chuyên_nghiệp mới nhân_viên độ ...
# 8414    interview thân_thiện constructive rounds equip...
# 8415    open organization recruitment fedback thư_giãn...
# 8416    keyboard mặc dùng vấn_cực tiếp_tục tiếp luôn c...
# Name: positive_clean, Length: 8411, dtype: object

# %%
df['negative_clean']
# Out:
# 0                         Cần phân_chuyên_nghiệp khả_năng
# 1                                            range maping
# 2                            outsourcing_mảng system_nghệ
# 3                                         forcus evaluate
# 4                                               văn_phòng
#                               ...
# 8412               vô Việt_Nam khóa học ít reily platform
# 8413                              hình_thể đóng_góp trình
# 8414                suốt tất_thể develop_bonding if_thông
# 8415    stil joiners clas_outdor không_hơn đổi đào âm_...
# 8416                                   Công cải_thiện hơn
# Name: negative_clean, Length: 8411, dtype: object

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Ghép toàn bộ văn bản trong cột "clean_text" thành một chuỗi
text = " ".join(df["positive_clean"].dropna().astype(str).tolist())

wordcloud = WordCloud(
    width=1000,
    height=600,
    background_color="white"
).generate(text)

# Hiển thị WordCloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("WordCloud từ đánh giá (positive_clean)", fontsize=16)
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Ghép toàn bộ văn bản trong cột "clean_text" thành một chuỗi
text = " ".join(df["negative_clean"].dropna().astype(str).tolist())

wordcloud = WordCloud(
    width=1000,
    height=600,
    background_color="white"
).generate(text)

# Hiển thị WordCloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("WordCloud từ đánh giá (negative_clean)", fontsize=16)
plt.show()

# %%
# from wordcloud import WordCloud
# import matplotlib.pyplot as plt

# # Custom stopwords: add "đi", "tốt"
# custom_stopwords = set(stopwords_lst + ["đi", "tốt","hơi"])

# def combine_negation_with_adj_fast(text):
#     """Combine 'không' or 'hơi' with the adjective/adverb/verb immediately after, optimized for speed."""
#     words = text.split()
#     if len(words) < 2:
#         return text
#     tags = pos_tag(' '.join(words))
#     # Ensure tags length matches words length
#     if len(tags) != len(words):
#         # fallback: do not combine if misalignment
#         return text
#     result = []
#     i = 0
#     while i < len(words):
#         word = words[i]
#         if word in ("không", "hơi") and i + 1 < len(words):
#             next_word, next_tag = tags[i + 1]
#             if next_tag.upper() in ("A", "AB", "V", "VB", "R"):
#                 result.append(f"{word}_{next_word}")
#                 i += 2
#                 continue
#         result.append(word)
#         i += 1
#     return " ".join(result)

# # Only process the negative_clean column once
# text = " ".join(df["negative_clean"].dropna().astype(str).tolist())
# text = combine_negation_with_adj_fast(text)

# wordcloud = WordCloud(
#     width=1000,
#     height=600,
#     background_color="white",
#     stopwords=custom_stopwords,
#     max_words=100  # Limit for speed
# ).generate(text)

# plt.figure(figsize=(12, 6))
# plt.imshow(wordcloud, interpolation ='bilinear')
# plt.axis("off")
# plt.title("WordCloud từ đánh giá (negative_clean)", fontsize=16)
# plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Vectorization
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, ngram_range=(1, 2))
positive_matrix = vectorizer.fit_transform(df['positive_clean'])
negative_matrix = vectorizer.transform(df['negative_clean'])

# %%
# LDA for positive feedback
n_topics_positive = 4

lda_positive = LatentDirichletAllocation(n_components=n_topics_positive, random_state=42)

lda_positive_matrix = lda_positive.fit_transform(positive_matrix)

# %%
lda_positive_matrix[:5]
# Out:
# array([[0.79608076, 0.07024451, 0.06698905, 0.06668568],
#        [0.20212305, 0.31780979, 0.41068408, 0.06938309],
#        [0.7956119 , 0.06498275, 0.0694104 , 0.06999494],
#        [0.10389677, 0.68872744, 0.10369234, 0.10368344],
#        [0.06486537, 0.53600432, 0.33697856, 0.06215175]])

# %% [markdown]
# ### Positive comment

# %%
from scipy.spatial.distance import cdist
distortions = []
K = range(1, 8)
for k in K:
    kmeansmodel = KMeans(n_clusters=k)
    kmeansmodel.fit(lda_positive_matrix)
    distortions.append(kmeansmodel.inertia_)

# %%
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# ### Chon k =4

# %%
# Bước 5: Phân cụm bằng KMeans trên vector chủ đề
n_clusters = 4
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df["cluster"] = kmeans.fit_predict(lda_positive_matrix)

# %%
# count samples per cluster
df["cluster"].value_counts()
# Out:
# cluster
# 0    2407
# 2    2227
# 1    2091
# 3    1686
# Name: count, dtype: int64

# %%
from sklearn.decomposition import PCA

# Bước 6: Giảm chiều bằng PCA để trực quan
pca_positive = PCA(n_components=2)
coords_positive = pca_positive.fit_transform(lda_positive_matrix)
df["x"] = coords_positive[:, 0]
df["y"] = coords_positive[:, 1]

# %%
# Bước 7: Vẽ biểu đồ cụm
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y", hue="cluster", palette="Set2")
plt.title("LDA + KMeans Clustering (Vietnamese Reviews)")
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.show()

# %%
# Bước 8: Hiển thị từ khóa đặc trưng mỗi topic
feature_names = vectorizer.get_feature_names_out()
for topic_idx, topic in enumerate(lda_positive.components_):
    top_words = [feature_names[i] for i in topic.argsort()[:-11:-1]]
    print(f"Chủ đề #{topic_idx + 1}: {', '.join(top_words)}")
# Out:
# Chủ đề #1: tốt, có, học, đẹp, nhân_viên, đào, thân_thiện, nhiều, trẻ, nghỉ
# Chủ đề #2: đẹp, thoải_mái, đi, overtime, tốt, văn_phòng, dự_án, vật_chất, nhiều, đào
# Chủ đề #3: đi, nhiều, được, tốt, có, làm, dự_án, không, trẻ, học
# Chủ đề #4: tốt, không, thân_thiện, môi_trường, rộng, trẻ, đồng_nghiệp, đẹp, rộng_rãi, đãi_ngộ

# %% [markdown]
# ### Negative Comment

# %%
n_topics_negative = 3

lda_negative = LatentDirichletAllocation(n_components=n_topics_negative, random_state=42)

lda_negative_matrix = lda_negative.fit_transform(negative_matrix)

# %%
lda_negative_matrix[:5]
# Out:
# array([[0.13818836, 0.34540484, 0.5164068 ],
#        [0.66636588, 0.16683965, 0.16679447],
#        [0.33333333, 0.33333333, 0.33333333],
#        [0.33333333, 0.33333333, 0.33333333],
#        [0.16670884, 0.65875869, 0.17453247]])

# %%
from scipy.spatial.distance import cdist
distortions = []
K = range(1, 8)
for k in K:
    kmeansmodel = KMeans(n_clusters=k)
    kmeansmodel.fit(lda_negative_matrix)
    distortions.append(kmeansmodel.inertia_)

# %%
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# ### Chon k=3

# %%
# Bước 5: Phân cụm bằng KMeans trên vector chủ đề
n_clusters = 4
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df["cluster"] = kmeans.fit_predict(lda_negative_matrix)

# %%
# count samples per cluster
df["cluster"].value_counts()
# Out:
# cluster
# 1    2667
# 0    2295
# 2    1821
# 3    1628
# Name: count, dtype: int64

# %%
from sklearn.decomposition import PCA

# Bước 6: Giảm chiều bằng PCA để trực quan
pca_negative = PCA(n_components=2)
coords_negative = pca_negative.fit_transform(lda_negative_matrix)
df["x"] = coords_negative[:, 0]
df["y"] = coords_negative[:, 1]

# %%
# Bước 7: Vẽ biểu đồ cụm
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y", hue="cluster", palette="Set2")
plt.title("LDA + KMeans Clustering (Vietnamese Reviews)")
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.show()

# %%
# Bước 8: Hiển thị từ khóa đặc trưng mỗi topic
feature_names = vectorizer.get_feature_names_out()
for topic_idx, topic in enumerate(lda_negative.components_):
    top_words = [feature_names[i] for i in topic.argsort()[:-11:-1]]
    print(f"Chủ đề #{topic_idx + 1}: {', '.join(top_words)}")
# Out:
# Chủ đề #1: tốt, nhân_viên, nghỉ, thưởng, chưa, có, gửi, đào, mong, làm
# Chủ đề #2: họp, chậm, đi, cũ, đánh_giá, tăng, ít, chán, quá, cấm
# Chủ đề #3: hơi, hơn, cần, cải_thiện, nhiều, lắm, không, thêm, thấp, dự_án

# %% [markdown]
# ## EVALUATE

# %%
def analyze_cluster_topic_distribution(df, lda_matrix, comment_type="Positive"):
    # Group by cluster and get mean topic distribution
    cluster_topic_dist = pd.DataFrame(lda_matrix).groupby(df['cluster']).mean()
    
    print(f"\n{comment_type.upper()} COMMENTS CLUSTER ANALYSIS")
    print("-" * 50)
    
    # For each cluster
    for cluster_id in range(len(cluster_topic_dist)):
        print(f"\nCluster {cluster_id+1}:")
        
        # Get topic distribution for this cluster
        topic_dist = cluster_topic_dist.iloc[cluster_id]
        
        # Sort topics by strength
        sorted_topics = sorted(enumerate(topic_dist), key=lambda x: x[1], reverse=True)
        
        # Print topic distribution
        print("Topic Distribution:")
        for topic_idx, strength in sorted_topics:
            print(f"Topic {topic_idx + 1}: {strength:.3f}")
        
        # Show cluster size
        cluster_size = (df['cluster'] == cluster_id).sum()
        print(f"Cluster size: {cluster_size} documents ({cluster_size/len(df)*100:.1f}%)")

print("\n" + "="*80)
print("ANALYZING TOPIC DOMINANCE IN CLUSTERS")
print("="*80)

# For positive comments (3 clusters)
kmeans_positive = KMeans(n_clusters=4, random_state=42)
df["cluster"] = kmeans_positive.fit_predict(lda_positive_matrix)
analyze_cluster_topic_distribution(df, lda_positive_matrix, "Positive")

# For negative comments (2 clusters)
kmeans_negative = KMeans(n_clusters=3, random_state=42)
df["cluster"] = kmeans_negative.fit_predict(lda_negative_matrix)
analyze_cluster_topic_distribution(df, lda_negative_matrix, "Negative")
# Out:
# ================================================================================
# ANALYZING TOPIC DOMINANCE IN CLUSTERS
# ================================================================================
#
# POSITIVE COMMENTS CLUSTER ANALYSIS
# --------------------------------------------------
#
# Cluster 1:
# Topic Distribution:
# Topic 1: 0.351
# Topic 4: 0.233
# Topic 3: 0.212
# Topic 2: 0.204
# Cluster size: 2407 documents (28.6%)
#
# Cluster 2:
# Topic Distribution:
# Topic 4: 0.325
# Topic 1: 0.265
# Topic 2: 0.206
# Topic 3: 0.205
# Cluster size: 2091 documents (24.9%)
#
# Cluster 3:
# Topic Distribution:
# Topic 2: 0.311
# Topic 1: 0.251
# Topic 4: 0.226
# Topic 3: 0.212
# Cluster size: 2227 documents (26.5%)
#
# Cluster 4:
# Topic Distribution:
# Topic 3: 0.296
# Topic 1: 0.259
# Topic 4: 0.236
# Topic 2: 0.209
# Cluster size: 1686 documents (20.0%)
#
# NEGATIVE COMMENTS CLUSTER ANALYSIS
# --------------------------------------------------
#
# Cluster 1:
# Topic Distribution:
# Topic 3: 0.368
# Topic 2: 0.332
# Topic 1: 0.300
# Cluster size: 3351 documents (39.8%)
#
# Cluster 2:
# Topic Distribution:
# Topic 3: 0.431
# Topic 1: 0.291
# Topic 2: 0.278
# Cluster size: 2984 documents (35.5%)
#
# Cluster 3:
# Topic Distribution:
# Topic 3: 0.366
# Topic 1: 0.360
# Topic 2: 0.274
# Cluster size: 2076 documents (24.7%)

# %%
# Group by company and cluster, count positive and negative reviews
summary = df.groupby(['Company Name', 'cluster', 'sentiment']).size().unstack(fill_value=0)

# Determine if feedback is mostly positive or negative in each cluster for each company
summary['category'] = summary.apply(
    lambda row: 'positive' if row.get('positive', 0) > row.get('negative', 0) else 'negative', axis=1
)

# For each company, list clusters with mostly positive and mostly negative feedback
result = summary.reset_index().groupby('Company Name').agg({
    'cluster': list,
    'category': list
})

for company, row in result.iterrows():
    positive_clusters = [c for c, cat in zip(row['cluster'], row['category']) if cat == 'positive']
    negative_clusters = [c for c, cat in zip(row['cluster'], row['category']) if cat == 'negative']
    print(f"Company: {company}")
    print(f"  Positive feedback in clusters: {positive_clusters}")
    print(f"  Negative feedback in clusters: {negative_clusters}\n")
# Out:
# Company: ANDPAD VietNam Co., Ltd
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: ARIS Vietnam
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: AZPLAYS Co., LTD
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: AZoom VietNam
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: Accenture
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: Adnovum Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Ahamove
#   Positive feedback in clusters: [1, 2]
#   Negative feedback in clusters: [0]
#
# Company: Allexceed Việt Nam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Alpaca Vietnam
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: Asilla
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Athena Studio
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Aviron
#   Positive feedback in clusters: [1]
#   Negative feedback in clusters: []
#
# Company: BAN VIEN CORPORATION
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Blue Belt Technology
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Bosch Global Software Technologies Company Limited
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Bray Leion Splash Group
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Breadstack Technologies Inc
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: CJ OLIVENETWORKS VINA CO., LTD
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: CODE88 COMPANY LIMITED
#   Positive feedback in clusters: [0]
#   Negative feedback in clusters: [2]
#
# Company: Capgemini Vietnam
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: Chotot
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: CodeLink
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Collaboration Betters The World (CBTW)
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Collaboration Betters The World - B.O.T
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Confluence Vietnam (HCMC)
#   Positive feedback in clusters: [1, 2]
#   Negative feedback in clusters: []
#
# Company: Creative Force
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Công Ty Cổ Phần Tập Đoàn Meey Land
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: DNSE
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: DatVietVAC
#   Positive feedback in clusters: []
#   Negative feedback in clusters: [0, 1, 2]
#
# Company: Datalogic Việt Nam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Deliveree On-Demand Logistics
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Dr.JOY
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: ELCA
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: East Agile
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Eastgate Software
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: Employment Hero
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Esoft Vietnam., Ltd
#   Positive feedback in clusters: [0]
#   Negative feedback in clusters: [1, 2]
#
# Company: Extreme Việt Nam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: F88
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: FE CREDIT
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: FPT Software
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: FireGroup
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: Floating Cube Studios
#   Positive feedback in clusters: [0, 2]
#   Negative feedback in clusters: [1]
#
# Company: Floware
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: Forix
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: GEEK UP
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: GENKI SYSTEM
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: GFT Technologies Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: GHN
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: GemCommerce
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: GeoComply (GeoTech Hub Vietnam)
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Grab (Vietnam) Ltd.
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Gsoft
#   Positive feedback in clusters: []
#   Negative feedback in clusters: [0, 1, 2]
#
# Company: HARAVAN
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: HCL Vietnam Company Limited
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: HDWEBSOFT
#   Positive feedback in clusters: [1]
#   Negative feedback in clusters: [0, 2]
#
# Company: HICAS
#   Positive feedback in clusters: [1, 2]
#   Negative feedback in clusters: [0]
#
# Company: HOIIO
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: HRS Group
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Hanatour Japan System Việt Nam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Hitachi Digital Services
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Hybrid Technologies
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: ICHIBA
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: IMT Solutions
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: IT Consultis
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: IVC (ISB Vietnam)
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: IVS
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: Infodation Vietnam
#   Positive feedback in clusters: [1, 2]
#   Negative feedback in clusters: []
#
# Company: Innotech Vietnam Corporation
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Intratech Corp
#   Positive feedback in clusters: [2]
#   Negative feedback in clusters: []
#
# Company: Intrepid Group Asia
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Jedi Technology
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Joblogic
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: KIS Việt Nam
#   Positive feedback in clusters: [0]
#   Negative feedback in clusters: [1]
#
# Company: KMS Healthcare
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: KMS Technology
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: KiotViet Corporation
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Koh Young Technology Inc
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: LARION
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: LG CNS Việt Nam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: LG Electronics Development Vietnam (LGEDV)
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: LHV Software
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Live Payments
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Luxoft Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: MB Bank
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: MEALSUITE
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: MINU Pte. Ltd
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: MONEY FORWARD VIETNAM CO.,LTD
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: [2]
#
# Company: MSB
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: M_Service (MoMo)
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Mcredit - Công ty Tài chính TNHH MB Shinsei
#   Positive feedback in clusters: [1, 2]
#   Negative feedback in clusters: [0]
#
# Company: NAB Innovation Centre Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: NAL Việt Nam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: NAVER VIETNAM
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: NEXON DEV VINA
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: NEYU Ltd.,
#   Positive feedback in clusters: [1, 2]
#   Negative feedback in clusters: []
#
# Company: NGS
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: NTT DATA VDS
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Nakivo
#   Positive feedback in clusters: []
#   Negative feedback in clusters: [0, 1, 2]
#
# Company: NashTech
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Neos Việt Nam
#   Positive feedback in clusters: [1]
#   Negative feedback in clusters: []
#
# Company: New Ocean IS
#   Positive feedback in clusters: [1, 2]
#   Negative feedback in clusters: [0]
#
# Company: OL Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: OLLI
#   Positive feedback in clusters: [0, 2]
#   Negative feedback in clusters: [1]
#
# Company: OMNIA SYSTEMS COMPANY LIMITED
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: ONE Tech Stop Vietnam Company Ltd
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Ohmyhotel&Co VN Co.,Ltd
#   Positive feedback in clusters: [2]
#   Negative feedback in clusters: []
#
# Company: One Mount Group
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Onpoint
#   Positive feedback in clusters: [1]
#   Negative feedback in clusters: [0, 2]
#
# Company: Optimizely
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Orient Software Development Corp.
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Outcubator
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Outpost24
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: PAL TECH
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: PAVE
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: PIXTA Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: PLAYSTUDIOS
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Panasonic Vietnam Group – Panasonic R&D Center Vietnam (PRDCV)
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Parcel Perform
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Persol Career Tech Studio Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Pixelz
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Pizza Hut Digital & Technology
#   Positive feedback in clusters: [1]
#   Negative feedback in clusters: [0]
#
# Company: PosApp
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: PwC Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: RAKSUL Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Rakus Vietnam Company
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Rakuten Fintech Vietnam Co., Ltd.
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Restaff – House Of Norway
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: SAPO
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: SCC Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: SECUTIX
#   Positive feedback in clusters: [2]
#   Negative feedback in clusters: [0, 1]
#
# Company: SGH Asia Ltd.
#   Positive feedback in clusters: [1]
#   Negative feedback in clusters: [0, 2]
#
# Company: SHINHAN DS
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: SMG Swiss Marketplace Group
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Saigon Technology
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Samsung Electronics HCMC CE Complex
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Scandinavian Software Park
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Semrush
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Seven System Vietnam
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: Shopee
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Simpson Strong-Tie Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Skedulo Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: SmartOSC
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Solazu JSC
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Sota Tek
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Spartan Dev Inc
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: TP Entertainment
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: TRUONG MINH THINH TECHNOLOGY JOINT STOCK COMPANY
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Techbase Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Techcombank
#   Positive feedback in clusters: [0, 2]
#   Negative feedback in clusters: [1]
#
# Company: The Access Group
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: The Rep. Office of STYL Solutions Pte. Ltd. In HCMC
#   Positive feedback in clusters: [1]
#   Negative feedback in clusters: [0, 2]
#
# Company: Thoughtworks Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Titan DMS
#   Positive feedback in clusters: [0, 2]
#   Negative feedback in clusters: [1]
#
# Company: Toshiba Software Development (Viet Nam) Co, Ltd
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Travala.com
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Trobz
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: Trusting Social
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: TymeX
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: ULTIMS
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: Unifiedpost
#   Positive feedback in clusters: [0, 2]
#   Negative feedback in clusters: []
#
# Company: VNDIRECT
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: VNG Corporation
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: VNPAY
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: VPBank
#   Positive feedback in clusters: [0, 2]
#   Negative feedback in clusters: [1]
#
# Company: Vareal Vietnam Co., Ltd
#   Positive feedback in clusters: [1]
#   Negative feedback in clusters: []
#
# Company: VietinBank
#   Positive feedback in clusters: [1]
#   Negative feedback in clusters: [0, 2]
#
# Company: Viettel Group
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Viettel Post (A Member of Viettel Group)
#   Positive feedback in clusters: [0, 1]
#   Negative feedback in clusters: []
#
# Company: Vitalify Asia
#   Positive feedback in clusters: [1, 2]
#   Negative feedback in clusters: [0]
#
# Company: Vulcan Labs
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: YOONG
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: YRGLM Việt Nam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: Yes4All
#   Positive feedback in clusters: [1, 2]
#   Negative feedback in clusters: [0]
#
# Company: Zuhlke Engineering Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: bbv Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: ekino Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: i3 DVR International
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: mgm technology partners Vietnam
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []
#
# Company: what3words
#   Positive feedback in clusters: [0, 1, 2]
#   Negative feedback in clusters: []

# %%
def assign_cluster_topics(lda_matrix, feature_names, n_words=10):
    """Create a mapping of cluster to their dominant topics and keywords"""
    cluster_topics = {}
    
    for topic_idx, topic in enumerate(lda_matrix.components_):
        top_words = [feature_names[i] for i in topic.argsort()[:-n_words-1:-1]]
        cluster_topics[topic_idx] = {
            'keywords': top_words,
            'description': ', '.join(top_words[:5])  
        }
    
    return cluster_topics

def analyze_company_feedback(df):
    """Analyze and display feedback for a specific company with company list display"""
    
    # Display available companies first
    print("Available companies:")
    companies = df['Company Name'].unique()
    for idx, company in enumerate(companies, 1):
        print(f"{idx}. {company}")
    
    while True:
        company_input = input("\nEnter company number or name (or 'q' to quit): ")
        
        if company_input.lower() == 'q':
            return
        
        # Handle numeric input
        if company_input.isdigit():
            idx = int(company_input) - 1
            if 0 <= idx < len(companies):
                company_id = companies[idx]
            else:
                print("Invalid company number. Please try again.")
                continue
        else:
            company_id = company_input
        
        # Verify company exists
        if company_id not in companies:
            print(f"Company '{company_id}' not found! Please try again.")
            continue
        
        # Get cluster topics
        positive_topics = assign_cluster_topics(lda_positive, vectorizer.get_feature_names_out())
        negative_topics = assign_cluster_topics(lda_negative, vectorizer.get_feature_names_out())
        
        # Filter data for the company
        company_data = df[df['Company Name'] == company_id]
        
        # Create markdown table
        markdown_table = """| Company Name | Positive Feedback + Dominant Topic | Negative Feedback + Dominant Topic |
|-------------|-----------------------------------|-----------------------------------|
"""
        
        # Get positive feedback clusters and their content
        pos_feedback = []
        pos_data = company_data[company_data['sentiment'] == 'positive']
        for cluster in pos_data['cluster'].unique():
            cluster_content = pos_data[pos_data['cluster'] == cluster]['positive_clean'].iloc[0]
            topic_desc = positive_topics[cluster]['description']
            pos_feedback.append(f"Cluster {cluster} ({topic_desc}):\n{cluster_content[:100]}...")
        
        # Get negative feedback clusters and their content
        neg_feedback = []
        neg_data = company_data[company_data['sentiment'] == 'negative']
        for cluster in neg_data['cluster'].unique():
            cluster_content = neg_data[neg_data['cluster'] == cluster]['negative_clean'].iloc[0]
            topic_desc = negative_topics[cluster]['description']
            neg_feedback.append(f"Cluster {cluster} ({topic_desc}):\n{cluster_content[:100]}...")
        
        # Add to table
        markdown_table += f"| {company_id} | {' '.join(pos_feedback) if pos_feedback else ''} | {' '.join(neg_feedback) if neg_feedback else ''} |"
        
        # Display results
        from IPython.display import display, Markdown
        display(Markdown(markdown_table))
        
        # Ask if user wants to analyze another company
        if input("\nAnalyze another company? (y/n): ").lower() != 'y':
            break

# Run the analysis
analyze_company_feedback(df)
# Out:
# Available companies:
# 1. Accenture
# 2. Adnovum Vietnam
# 3. Ahamove
# 4. Allexceed Việt Nam
# 5. Alpaca Vietnam
# 6. ANDPAD VietNam Co., Ltd
# 7. ARIS Vietnam
# 8. Asilla
# 9. Athena Studio
# 10. Aviron
# 11. AZoom VietNam
# 12. AZPLAYS Co., LTD
# 13. BAN VIEN CORPORATION
# 14. bbv Vietnam
# 15. Blue Belt Technology
# 16. Bosch Global Software Technologies Company Limited
# 17. Breadstack Technologies Inc
# 18. Capgemini Vietnam
# 19. Chotot
# 20. CJ OLIVENETWORKS VINA CO., LTD
# 21. CODE88 COMPANY LIMITED
# 22. CodeLink
# 23. Collaboration Betters The World - B.O.T
# 24. Collaboration Betters The World (CBTW)
# 25. Confluence Vietnam (HCMC)
# 26. Công Ty Cổ Phần Tập Đoàn Meey Land
# 27. Creative Force
# 28. Datalogic Việt Nam
# 29. DatVietVAC
# 30. Deliveree On-Demand Logistics
# 31. DNSE
# 32. Dr.JOY
# 33. East Agile
# 34. Eastgate Software
# 35. ekino Vietnam
# 36. ELCA
# 37. Employment Hero
# 38. Esoft Vietnam., Ltd
# 39. Extreme Việt Nam
# 40. F88
# 41. FE CREDIT
# 42. FireGroup
# 43. Floating Cube Studios
# 44. Floware
# 45. Forix
# 46. FPT Software
# 47. GEEK UP
# 48. GemCommerce
# 49. GENKI SYSTEM
# 50. GeoComply (GeoTech Hub Vietnam)
# 51. GFT Technologies Vietnam
# 52. GHN
# 53. Grab (Vietnam) Ltd.
# 54. Gsoft
# 55. Hanatour Japan System Việt Nam
# 56. HARAVAN
# 57. HCL Vietnam Company Limited
# 58. HDWEBSOFT
# 59. HICAS
# 60. Hitachi Digital Services
# 61. HOIIO
# 62. HRS Group
# 63. Hybrid Technologies
# 64. i3 DVR International
# 65. ICHIBA
# 66. IMT Solutions
# 67. Infodation Vietnam
# 68. Innotech Vietnam Corporation
# 69. Intratech Corp
# 70. Intrepid Group Asia
# 71. IT Consultis
# 72. IVC (ISB Vietnam)
# 73. IVS
# 74. Jedi Technology
# 75. Joblogic
# 76. KiotViet Corporation
# 77. KIS Việt Nam
# 78. KMS Healthcare
# 79. KMS Technology
# 80. Koh Young Technology Inc
# 81. LARION
# 82. LG CNS Việt Nam
# 83. LG Electronics Development Vietnam (LGEDV)
# 84. LHV Software
# 85. Live Payments
# 86. Luxoft Vietnam
# 87. MB Bank
# 88. Mcredit - Công ty Tài chính TNHH MB Shinsei
# 89. MEALSUITE
# 90. mgm technology partners Vietnam
# 91. MINU Pte. Ltd
# 92. Bray Leion Splash Group
# 93. MONEY FORWARD VIETNAM CO.,LTD
# 94. MSB
# 95. M_Service (MoMo)
# 96. NAB Innovation Centre Vietnam
# 97. Nakivo
# 98. NAL Việt Nam
# 99. NashTech
# 100. NAVER VIETNAM
# 101. Neos Việt Nam
# 102. New Ocean IS
# 103. NEXON DEV VINA
# 104. NEYU Ltd.,
# 105. NGS
# 106. NTT DATA VDS
# 107. Ohmyhotel&Co VN Co.,Ltd
# 108. OLLI
# 109. OL Vietnam
# 110. OMNIA SYSTEMS COMPANY LIMITED
# 111. One Mount Group
# 112. ONE Tech Stop Vietnam Company Ltd
# 113. Onpoint
# 114. Optimizely
# 115. Orient Software Development Corp.
# 116. Outcubator
# 117. Outpost24
# 118. PAL TECH
# 119. Panasonic Vietnam Group – Panasonic R&D Center Vietnam (PRDCV)
# 120. Parcel Perform
# 121. PAVE
# 122. Persol Career Tech Studio Vietnam
# 123. Pixelz
# 124. PIXTA Vietnam
# 125. Pizza Hut Digital & Technology
# 126. PLAYSTUDIOS
# 127. PosApp
# 128. PwC Vietnam
# 129. RAKSUL Vietnam
# 130. Rakus Vietnam Company
# 131. Rakuten Fintech Vietnam Co., Ltd.
# 132. Restaff – House Of Norway
# 133. Saigon Technology
# 134. Samsung Electronics HCMC CE Complex
# 135. SAPO
# 136. Scandinavian Software Park
# 137. SCC Vietnam
# 138. SECUTIX
# 139. Semrush
# 140. Seven System Vietnam
# 141. SGH Asia Ltd.
# 142. SHINHAN DS
# 143. Shopee
# 144. Simpson Strong-Tie Vietnam
# 145. Skedulo Vietnam
# 146. SmartOSC
# 147. SMG Swiss Marketplace Group
# 148. Solazu JSC
# 149. Sota Tek
# 150. Spartan Dev Inc
# 151. Techbase Vietnam
# 152. Techcombank
# 153. The Access Group
# 154. The Rep. Office of STYL Solutions Pte. Ltd. In HCMC
# 155. Thoughtworks Vietnam
# 156. Titan DMS
# 157. Toshiba Software Development (Viet Nam) Co, Ltd
# 158. TP Entertainment
# 159. Travala.com
# 160. Trobz
# 161. TRUONG MINH THINH TECHNOLOGY JOINT STOCK COMPANY
# 162. Trusting Social
# 163. TymeX
# 164. ULTIMS
# 165. Unifiedpost
# 166. Vareal Vietnam Co., Ltd
# 167. VietinBank
# 168. Viettel Group
# 169. Viettel Post (A Member of Viettel Group)
# 170. Vitalify Asia
# 171. VNDIRECT
# 172. VNG Corporation
# 173. VNPAY
# 174. VPBank
# 175. Vulcan Labs
# 176. what3words
# 177. Yes4All
# 178. YOONG
# 179. YRGLM Việt Nam
# 180. Zuhlke Engineering Vietnam
# | Company Name | Positive Feedback + Dominant Topic | Negative Feedback + Dominant Topic |
# |-------------|-----------------------------------|-----------------------------------|
# | Allexceed Việt Nam | Cluster 2 (đi, nhiều, được, tốt, có):
# Làm sử_dụng trình kể lắng_nghệ cũ học... Cluster 0 (tốt, có, học, đẹp, nhân_viên):
# đa_hòa kéo Không... Cluster 1 (đẹp, thoải_mái, đi, overtime, tốt):
# tốt đồng_nghiệp đồng_cởi Được học Ít đủ tốt Ít... | Cluster 2 (hơi, hơn, cần, cải_thiện, nhiều):
# gửi hách nghỉ building vận_động quyên uống đa oursource_nghệ... |

# %%
def analyze_company_feedback(df):
    # Display available companies
    print("Available companies:")
    for idx, company in enumerate(df['Company Name'].unique()):
        print(f"{idx + 1}. {company}")
    
    # Get user input
    while True:
        try:
            company_id = input("\nEnter company number or name (or 'q' to quit): ")
            
            if company_id.lower() == 'q':
                return
            
            # Handle numeric input
            if company_id.isdigit():
                idx = int(company_id) - 1
                if 0 <= idx < len(df['Company Name'].unique()):
                    company_id = df['Company Name'].unique()[idx]
                else:
                    print("Invalid company number. Please try again.")
                    continue
            
            # Check if company exists
            if company_id not in df['Company Name'].unique():
                print("Company not found. Please try again.")
                continue
            
            # Filter data for selected company
            company_data = df[df['Company Name'] == company_id]
            
            # Create and display markdown table for the company
            markdown_table = """| Company Name | Positive Feedback + Dominant Topic | Negative Feedback + Dominant Topic |
|-------------|-----------------------------------|-----------------------------------|
"""
            
            # Get positive clusters and their content
            pos_clusters = company_data[
                (company_data['sentiment'] == 'positive')
            ].groupby('cluster')['text'].first()
            pos_feedback = "\n".join([f"Cluster {c}: {t[:100]}..." for c, t in pos_clusters.items()])
            
            # Get negative clusters and their content
            neg_clusters = company_data[
                (company_data['sentiment'] == 'negative')
            ].groupby('cluster')['text'].first()
            neg_feedback = "\n".join([f"Cluster {c}: {t[:100]}..." for c, t in neg_clusters.items()])
            
            # Add row to table
            markdown_table += f"| {company_id} | {pos_feedback if not pos_clusters.empty else ''} | {neg_feedback if not neg_clusters.empty else ''} |\n"
            
            from IPython.display import display, Markdown
            display(Markdown(markdown_table))
            
            # Ask if user wants to analyze another company
            if input("\nAnalyze another company? (y/n): ").lower() != 'y':
                break
                
        except Exception as e:
            print(f"Error: {e}")
            print("Please try again.")

# Use the function
analyze_company_feedback(df)
# Out:
# Available companies:
# 1. Accenture
# 2. Adnovum Vietnam
# 3. Ahamove
# 4. Allexceed Việt Nam
# 5. Alpaca Vietnam
# 6. ANDPAD VietNam Co., Ltd
# 7. ARIS Vietnam
# 8. Asilla
# 9. Athena Studio
# 10. Aviron
# 11. AZoom VietNam
# 12. AZPLAYS Co., LTD
# 13. BAN VIEN CORPORATION
# 14. bbv Vietnam
# 15. Blue Belt Technology
# 16. Bosch Global Software Technologies Company Limited
# 17. Breadstack Technologies Inc
# 18. Capgemini Vietnam
# 19. Chotot
# 20. CJ OLIVENETWORKS VINA CO., LTD
# 21. CODE88 COMPANY LIMITED
# 22. CodeLink
# 23. Collaboration Betters The World - B.O.T
# 24. Collaboration Betters The World (CBTW)
# 25. Confluence Vietnam (HCMC)
# 26. Công Ty Cổ Phần Tập Đoàn Meey Land
# 27. Creative Force
# 28. Datalogic Việt Nam
# 29. DatVietVAC
# 30. Deliveree On-Demand Logistics
# 31. DNSE
# 32. Dr.JOY
# 33. East Agile
# 34. Eastgate Software
# 35. ekino Vietnam
# 36. ELCA
# 37. Employment Hero
# 38. Esoft Vietnam., Ltd
# 39. Extreme Việt Nam
# 40. F88
# 41. FE CREDIT
# 42. FireGroup
# 43. Floating Cube Studios
# 44. Floware
# 45. Forix
# 46. FPT Software
# 47. GEEK UP
# 48. GemCommerce
# 49. GENKI SYSTEM
# 50. GeoComply (GeoTech Hub Vietnam)
# 51. GFT Technologies Vietnam
# 52. GHN
# 53. Grab (Vietnam) Ltd.
# 54. Gsoft
# 55. Hanatour Japan System Việt Nam
# 56. HARAVAN
# 57. HCL Vietnam Company Limited
# 58. HDWEBSOFT
# 59. HICAS
# 60. Hitachi Digital Services
# 61. HOIIO
# 62. HRS Group
# 63. Hybrid Technologies
# 64. i3 DVR International
# 65. ICHIBA
# 66. IMT Solutions
# 67. Infodation Vietnam
# 68. Innotech Vietnam Corporation
# 69. Intratech Corp
# 70. Intrepid Group Asia
# 71. IT Consultis
# 72. IVC (ISB Vietnam)
# 73. IVS
# 74. Jedi Technology
# 75. Joblogic
# 76. KiotViet Corporation
# 77. KIS Việt Nam
# 78. KMS Healthcare
# 79. KMS Technology
# 80. Koh Young Technology Inc
# 81. LARION
# 82. LG CNS Việt Nam
# 83. LG Electronics Development Vietnam (LGEDV)
# 84. LHV Software
# 85. Live Payments
# 86. Luxoft Vietnam
# 87. MB Bank
# 88. Mcredit - Công ty Tài chính TNHH MB Shinsei
# 89. MEALSUITE
# 90. mgm technology partners Vietnam
# 91. MINU Pte. Ltd
# 92. Bray Leion Splash Group
# 93. MONEY FORWARD VIETNAM CO.,LTD
# 94. MSB
# 95. M_Service (MoMo)
# 96. NAB Innovation Centre Vietnam
# 97. Nakivo
# 98. NAL Việt Nam
# 99. NashTech
# 100. NAVER VIETNAM
# 101. Neos Việt Nam
# 102. New Ocean IS
# 103. NEXON DEV VINA
# 104. NEYU Ltd.,
# 105. NGS
# 106. NTT DATA VDS
# 107. Ohmyhotel&Co VN Co.,Ltd
# 108. OLLI
# 109. OL Vietnam
# 110. OMNIA SYSTEMS COMPANY LIMITED
# 111. One Mount Group
# 112. ONE Tech Stop Vietnam Company Ltd
# 113. Onpoint
# 114. Optimizely
# 115. Orient Software Development Corp.
# 116. Outcubator
# 117. Outpost24
# 118. PAL TECH
# 119. Panasonic Vietnam Group – Panasonic R&D Center Vietnam (PRDCV)
# 120. Parcel Perform
# 121. PAVE
# 122. Persol Career Tech Studio Vietnam
# 123. Pixelz
# 124. PIXTA Vietnam
# 125. Pizza Hut Digital & Technology
# 126. PLAYSTUDIOS
# 127. PosApp
# 128. PwC Vietnam
# 129. RAKSUL Vietnam
# 130. Rakus Vietnam Company
# 131. Rakuten Fintech Vietnam Co., Ltd.
# 132. Restaff – House Of Norway
# 133. Saigon Technology
# 134. Samsung Electronics HCMC CE Complex
# 135. SAPO
# 136. Scandinavian Software Park
# 137. SCC Vietnam
# 138. SECUTIX
# 139. Semrush
# 140. Seven System Vietnam
# 141. SGH Asia Ltd.
# 142. SHINHAN DS
# 143. Shopee
# 144. Simpson Strong-Tie Vietnam
# 145. Skedulo Vietnam
# 146. SmartOSC
# 147. SMG Swiss Marketplace Group
# 148. Solazu JSC
# 149. Sota Tek
# 150. Spartan Dev Inc
# 151. Techbase Vietnam
# 152. Techcombank
# 153. The Access Group
# 154. The Rep. Office of STYL Solutions Pte. Ltd. In HCMC
# 155. Thoughtworks Vietnam
# 156. Titan DMS
# 157. Toshiba Software Development (Viet Nam) Co, Ltd
# 158. TP Entertainment
# 159. Travala.com
# 160. Trobz
# 161. TRUONG MINH THINH TECHNOLOGY JOINT STOCK COMPANY
# 162. Trusting Social
# 163. TymeX
# 164. ULTIMS
# 165. Unifiedpost
# 166. Vareal Vietnam Co., Ltd
# 167. VietinBank
# 168. Viettel Group
# 169. Viettel Post (A Member of Viettel Group)
# 170. Vitalify Asia
# 171. VNDIRECT
# 172. VNG Corporation
# 173. VNPAY
# 174. VPBank
# 175. Vulcan Labs
# 176. what3words
# 177. Yes4All
# 178. YOONG
# 179. YRGLM Việt Nam
# 180. Zuhlke Engineering Vietnam
# Error: 'Column not found: text'
# Please try again.
# Error: 'Column not found: text'
# Please try again.
# Error: 'Column not found: text'
# Please try again.

# %%
df.head()
# Out:
#    id Company Name        Cmt_day  \
# 0   4    Accenture     March 2025
# 1   4    Accenture   January 2025
# 2   4    Accenture   October 2023
# 3   4    Accenture  February 2025
# 4   4    Accenture  February 2023
#
#                                                Title  \
# 0  Môi trường thoải mái, ít áp lực, có thể làm vi...
# 1                        Công ty trẻ trung năng động
# 2               Môi trường làm việc thoải mái vui vẻ
# 3                       good environment for fresher
# 4              Môi trường làm việc thoải mái, vui vẻ
#
#                                         What I liked  \
# 0  Môi trường thoải mái, ít áp lực, có thể làm vi...
# 1  Cơ sở vật chất đẹp, công ty trẻ trung năng độn...
# 2  Mội người thân thiện, giúp đỡ lẫn nhau. Chương...
# 3  good env. for fresher to learn and improve the...
# 4  - Văn phòng đẹp, cơ sở vật chất tốt\n- Sếp và ...
#
#                          Suggestions for improvement  Rating  \
# 0  Cần đánh giá KPI khách quan và phân chia công ...       4
# 1  Nên nghiên cứu lại range lương của thì trường....       4
# 2  Do công ty làm outsourcing về mảng system nên ...       3
# 3  Need to forcus more on benefit and evaluate co...       3
# 4  - Phát triển văn phòng để rộng rãi hơn\n- Công...       4
#
#    Salary & benefits  Training & learning  Management cares about me  ...  \
# 0                  4                    4                          4  ...
# 1                  3                    4                          4  ...
# 2                  3                    3                          3  ...
# 3                  2                    2                          3  ...
# 4                  3                    4                          4  ...
#
#    Office & workspace  Recommend?  \
# 0                   4         Yes
# 1                   5         Yes
# 2                   3         Yes
# 3                   4          No
# 4                   3         Yes
#
#                                        positive_text  \
# 0  Môi trường thoải mái, ít áp lực, có thể làm vi...
# 1  Cơ sở vật chất đẹp, công ty trẻ trung năng độn...
# 2  Mội người thân thiện, giúp đỡ lẫn nhau. Chương...
# 3  good env. for fresher to learn and improve the...
# 4  - Văn phòng đẹp, cơ sở vật chất tốt\n- Sếp và ...
#
#                                        negative_text sentiment  \
# 0  Cần đánh giá KPI khách quan và phân chia công ...  positive
# 1  Nên nghiên cứu lại range lương của thì trường....  positive
# 2  Do công ty làm outsourcing về mảng system nên ...   neutral
# 3  Need to forcus more on benefit and evaluate co...   neutral
# 4  - Phát triển văn phòng để rộng rãi hơn\n- Công...  positive
#
#                                       positive_clean  \
# 0  thoải_mái hybrid thỏa_thuận tốt đủ dịch_vụ cải...
# 1                          đẹp trẻ kết_hợp dự_án thể
# 2  thân_thiện lẫn chuyên_nghiệp tổ_chức Khá yêu_c...
# 3                               ability opened teams
# 4  đẹp vật_chất tốt đồng_nghiệp Đồng_nghiệp vẻ th...
#
#                     negative_clean cluster         x         y
# 0  Cần phân_chuyên_nghiệp khả_năng       1  0.175233  0.132742
# 1                     range maping       2 -0.318469 -0.302394
# 2     outsourcing_mảng system_nghệ       0 -0.067230  0.018923
# 3                  forcus evaluate       0 -0.067230  0.018923
# 4                        văn_phòng       0 -0.211291  0.390581
#
# [5 rows x 21 columns]

# %%
def analyze_company_feedback(df):
    # Display available companies
    print("Available companies:")
    companies = df['Company Name'].unique()
    for idx, company in enumerate(companies, 1):
        print(f"{idx}. {company}")
    
    while True:
        company_input = input("\nEnter company number or name (or 'q' to quit): ")
        
        if company_input.lower() == 'q':
            return
        
        # Handle numeric input
        if company_input.isdigit():
            idx = int(company_input) - 1
            if 0 <= idx < len(companies):
                company_id = companies[idx]
            else:
                print("Invalid company number. Please try again.")
                continue
        else:
            company_id = company_input
            
        if company_id not in companies:
            print(f"Company '{company_id}' not found! Please try again.")
            continue
            
        # Get topic descriptions
        positive_topics = assign_cluster_topics(lda_positive, vectorizer.get_feature_names_out())
        negative_topics = assign_cluster_topics(lda_negative, vectorizer.get_feature_names_out())
        
        company_data = df[df['Company Name'] == company_id]
        
        from IPython.display import display, Markdown
        
        output = f"""
# {company_id}

## Positive Topics:
"""
        # Add positive topics
        pos_data = company_data[company_data['sentiment'] == 'positive']
        for cluster in pos_data['cluster'].unique():
            topic_desc = positive_topics[cluster]['description']
            output += f"- Cluster {cluster}: {topic_desc}\n"
            
        output += "\n## Negative Topics:"
        
        # Add negative topics
        neg_data = company_data[company_data['sentiment'] == 'negative']
        for cluster in neg_data['cluster'].unique():
            topic_desc = negative_topics[cluster]['description']
            output += f"\n- Cluster {cluster}: {topic_desc}"
            
        display(Markdown(output))
        
        if input("\nAnalyze another company? (y/n): ").lower() != 'y':
            break

# Run the analysis
analyze_company_feedback(df)
# Out:
# Available companies:
# 1. Accenture
# 2. Adnovum Vietnam
# 3. Ahamove
# 4. Allexceed Việt Nam
# 5. Alpaca Vietnam
# 6. ANDPAD VietNam Co., Ltd
# 7. ARIS Vietnam
# 8. Asilla
# 9. Athena Studio
# 10. Aviron
# 11. AZoom VietNam
# 12. AZPLAYS Co., LTD
# 13. BAN VIEN CORPORATION
# 14. bbv Vietnam
# 15. Blue Belt Technology
# 16. Bosch Global Software Technologies Company Limited
# 17. Breadstack Technologies Inc
# 18. Capgemini Vietnam
# 19. Chotot
# 20. CJ OLIVENETWORKS VINA CO., LTD
# 21. CODE88 COMPANY LIMITED
# 22. CodeLink
# 23. Collaboration Betters The World - B.O.T
# 24. Collaboration Betters The World (CBTW)
# 25. Confluence Vietnam (HCMC)
# 26. Công Ty Cổ Phần Tập Đoàn Meey Land
# 27. Creative Force
# 28. Datalogic Việt Nam
# 29. DatVietVAC
# 30. Deliveree On-Demand Logistics
# 31. DNSE
# 32. Dr.JOY
# 33. East Agile
# 34. Eastgate Software
# 35. ekino Vietnam
# 36. ELCA
# 37. Employment Hero
# 38. Esoft Vietnam., Ltd
# 39. Extreme Việt Nam
# 40. F88
# 41. FE CREDIT
# 42. FireGroup
# 43. Floating Cube Studios
# 44. Floware
# 45. Forix
# 46. FPT Software
# 47. GEEK UP
# 48. GemCommerce
# 49. GENKI SYSTEM
# 50. GeoComply (GeoTech Hub Vietnam)
# 51. GFT Technologies Vietnam
# 52. GHN
# 53. Grab (Vietnam) Ltd.
# 54. Gsoft
# 55. Hanatour Japan System Việt Nam
# 56. HARAVAN
# 57. HCL Vietnam Company Limited
# 58. HDWEBSOFT
# 59. HICAS
# 60. Hitachi Digital Services
# 61. HOIIO
# 62. HRS Group
# 63. Hybrid Technologies
# 64. i3 DVR International
# 65. ICHIBA
# 66. IMT Solutions
# 67. Infodation Vietnam
# 68. Innotech Vietnam Corporation
# 69. Intratech Corp
# 70. Intrepid Group Asia
# 71. IT Consultis
# 72. IVC (ISB Vietnam)
# 73. IVS
# 74. Jedi Technology
# 75. Joblogic
# 76. KiotViet Corporation
# 77. KIS Việt Nam
# 78. KMS Healthcare
# 79. KMS Technology
# 80. Koh Young Technology Inc
# 81. LARION
# 82. LG CNS Việt Nam
# 83. LG Electronics Development Vietnam (LGEDV)
# 84. LHV Software
# 85. Live Payments
# 86. Luxoft Vietnam
# 87. MB Bank
# 88. Mcredit - Công ty Tài chính TNHH MB Shinsei
# 89. MEALSUITE
# 90. mgm technology partners Vietnam
# 91. MINU Pte. Ltd
# 92. Bray Leion Splash Group
# 93. MONEY FORWARD VIETNAM CO.,LTD
# 94. MSB
# 95. M_Service (MoMo)
# 96. NAB Innovation Centre Vietnam
# 97. Nakivo
# 98. NAL Việt Nam
# 99. NashTech
# 100. NAVER VIETNAM
# 101. Neos Việt Nam
# 102. New Ocean IS
# 103. NEXON DEV VINA
# 104. NEYU Ltd.,
# 105. NGS
# 106. NTT DATA VDS
# 107. Ohmyhotel&Co VN Co.,Ltd
# 108. OLLI
# 109. OL Vietnam
# 110. OMNIA SYSTEMS COMPANY LIMITED
# 111. One Mount Group
# 112. ONE Tech Stop Vietnam Company Ltd
# 113. Onpoint
# 114. Optimizely
# 115. Orient Software Development Corp.
# 116. Outcubator
# 117. Outpost24
# 118. PAL TECH
# 119. Panasonic Vietnam Group – Panasonic R&D Center Vietnam (PRDCV)
# 120. Parcel Perform
# 121. PAVE
# 122. Persol Career Tech Studio Vietnam
# 123. Pixelz
# 124. PIXTA Vietnam
# 125. Pizza Hut Digital & Technology
# 126. PLAYSTUDIOS
# 127. PosApp
# 128. PwC Vietnam
# 129. RAKSUL Vietnam
# 130. Rakus Vietnam Company
# 131. Rakuten Fintech Vietnam Co., Ltd.
# 132. Restaff – House Of Norway
# 133. Saigon Technology
# 134. Samsung Electronics HCMC CE Complex
# 135. SAPO
# 136. Scandinavian Software Park
# 137. SCC Vietnam
# 138. SECUTIX
# 139. Semrush
# 140. Seven System Vietnam
# 141. SGH Asia Ltd.
# 142. SHINHAN DS
# 143. Shopee
# 144. Simpson Strong-Tie Vietnam
# 145. Skedulo Vietnam
# 146. SmartOSC
# 147. SMG Swiss Marketplace Group
# 148. Solazu JSC
# 149. Sota Tek
# 150. Spartan Dev Inc
# 151. Techbase Vietnam
# 152. Techcombank
# 153. The Access Group
# 154. The Rep. Office of STYL Solutions Pte. Ltd. In HCMC
# 155. Thoughtworks Vietnam
# 156. Titan DMS
# 157. Toshiba Software Development (Viet Nam) Co, Ltd
# 158. TP Entertainment
# 159. Travala.com
# 160. Trobz
# 161. TRUONG MINH THINH TECHNOLOGY JOINT STOCK COMPANY
# 162. Trusting Social
# 163. TymeX
# 164. ULTIMS
# 165. Unifiedpost
# 166. Vareal Vietnam Co., Ltd
# 167. VietinBank
# 168. Viettel Group
# 169. Viettel Post (A Member of Viettel Group)
# 170. Vitalify Asia
# 171. VNDIRECT
# 172. VNG Corporation
# 173. VNPAY
# 174. VPBank
# 175. Vulcan Labs
# 176. what3words
# 177. Yes4All
# 178. YOONG
# 179. YRGLM Việt Nam
# 180. Zuhlke Engineering Vietnam
# # Adnovum Vietnam
#
# ## Positive Topics:
# - Cluster 0: tốt, có, học, đẹp, nhân_viên
# - Cluster 1: đẹp, thoải_mái, đi, overtime, tốt
# - Cluster 2: đi, nhiều, được, tốt, có
#
# ## Negative Topics:
